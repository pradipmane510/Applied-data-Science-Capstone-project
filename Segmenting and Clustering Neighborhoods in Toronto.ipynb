# %% [markdown]
# ### Importing packages

# %%
from bs4 import BeautifulSoup
import requests
import lxml.html as lh
import pandas as pd

# %% [markdown]
# ### read the web page and store the content between tr tag

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %% [markdown]
# ### store the Header row of Table

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    col.append((name[0:]))

# %% [markdown]
# ### Store the contains of Table and check column Borough for 'Not assigned'
# ### Check column neighborhood for 'Not assigned' if so replace with its Borough value

# %%
soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find('table')
trs = table.find_all('tr')
rows = []
for tr in trs:
    i = tr.find_all('td')
    if i:
        rows.append(i)
        
lst = []
for row in rows:
    postalcode = row[0].text.rstrip()
    borough = row[1].text.rstrip()
    neighborhood = row[2].text.rstrip()
    if borough != 'Not assigned':
        if neighborhood == 'Not assigned':
            neighborhood = borough
        lst.append([postalcode, borough, neighborhood])

# %%
df = pd.DataFrame(lst, columns=col)
df
# Out:
#     Postal Code\n         Borough\n  \
# 0             M3A        North York
# 1             M4A        North York
# 2             M5A  Downtown Toronto
# 3             M6A        North York
# 4             M7A  Downtown Toronto
# 5             M9A         Etobicoke
# 6             M1B       Scarborough
# 7             M3B        North York
# 8             M4B         East York
# 9             M5B  Downtown Toronto
# 10            M6B        North York
# 11            M9B         Etobicoke
# 12            M1C       Scarborough
# 13            M3C        North York
# 14            M4C         East York
# 15            M5C  Downtown Toronto
# 16            M6C              York
# 17            M9C         Etobicoke
# 18            M1E       Scarborough
# 19            M4E      East Toronto
# 20            M5E  Downtown Toronto
# 21            M6E              York
# 22            M1G       Scarborough
# 23            M4G         East York
# 24            M5G  Downtown Toronto
# 25            M6G  Downtown Toronto
# 26            M1H       Scarborough
# 27            M2H        North York
# 28            M3H        North York
# 29            M4H         East York
# ..            ...               ...
# 73            M4R   Central Toronto
# 74            M5R   Central Toronto
# 75            M6R      West Toronto
# 76            M7R       Mississauga
# 77            M9R         Etobicoke
# 78            M1S       Scarborough
# 79            M4S   Central Toronto
# 80            M5S  Downtown Toronto
# 81            M6S      West Toronto
# 82            M1T       Scarborough
# 83            M4T   Central Toronto
# 84            M5T  Downtown Toronto
# 85            M1V       Scarborough
# 86            M4V   Central Toronto
# 87            M5V  Downtown Toronto
# 88            M8V         Etobicoke
# 89            M9V         Etobicoke
# 90            M1W       Scarborough
# 91            M4W  Downtown Toronto
# 92            M5W  Downtown Toronto
# 93            M8W         Etobicoke
# 94            M9W         Etobicoke
# 95            M1X       Scarborough
# 96            M4X  Downtown Toronto
# 97            M5X  Downtown Toronto
# 98            M8X         Etobicoke
# 99            M4Y  Downtown Toronto
# 100           M7Y      East Toronto
# 101           M8Y         Etobicoke
# 102           M8Z         Etobicoke
#
#                                         Neighborhood\n
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# 5                                     Islington Avenue
# 6                                       Malvern, Rouge
# 7                                            Don Mills
# 8                      Parkview Hill, Woodbine Gardens
# 9                             Garden District, Ryerson
# 10                                           Glencairn
# 11   West Deane Park, Princess Gardens, Martin Grov...
# 12              Rouge Hill, Port Union, Highland Creek
# 13                                           Don Mills
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Wilson Heights, Downsview North
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, St. Phillips, Martin Grove ...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      University of Toronto, Harbord
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Tam O'Shanter, Sullivan
# 83                         Moore Park, Summerhill East
# 84           Kensington Market, Chinatown, Grange Park
# 85   Milliken, Agincourt North, Steeles East, L'Amo...
# 86   Summerhill West, Rathnelly, South Hill, Forest...
# 87   CN Tower, King and Spadina, Railway Lands, Har...
# 88        New Toronto, Mimico South, Humber Bay Shores
# 89   South Steeles, Silverstone, Humbergate, Jamest...
# 90                       Steeles West, L'Amoreaux West
# 91                                            Rosedale
# 92                                      Stn A PO Boxes
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                         St. James Town, Cabbagetown
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing Centre
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# ### check if 'M5A' example is done correctly

# %%
df.loc[df['Postal Code\n'] == 'M5A']
# Out:
#   Postal Code\n         Borough\n             Neighborhood\n
# 2           M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# ### prinitng the shape of file

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Store the dataframe in CSV file

# %%
dfgeo = pd.read_csv("http://cocl.us/Geospatial_data")

# %%
dfgeo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Change the column name of df dataframe Postel code same as to dfgeo dataframe

# %%
df.rename(columns={'Postal Code\n': 'Postal Code'}, inplace=True)

# %% [markdown]
# merge 2 dataframes i.e. df and dfgeo based on a PostalCode column as per requirment

# %%
df2 = pd.merge(df, dfgeo, on="Postal Code", how='left')

# %%
df2.head()
# Out:
#   Postal Code         Borough\n                               Neighborhood\n  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ### Importing More Required packages

# %%
from geopy.geocoders import Nominatim
import json
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)

# %% [markdown]
# ### Toronto Map

# %%
geolocator = Nominatim(user_agent="coursera")
address = 'Toronto'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
my_map = folium.Map(location=[latitude, longitude], zoom_start=11)

# %% [markdown]
# ### adding markers to map

# %%
for lat, lng, label in zip(df2['Latitude'], df2['Longitude'], df2['Postal Code']):
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(my_map)

# %% [markdown]
# ### Will analyze with FourSquare

# %%
CLIENT_ID = '...' # Foursquare ID hiding by me 
CLIENT_SECRET = '...' # Foursquare Secret hiding by me
VERSION = '20180605' # API version

# %%
df2.set_index('Postal Code', inplace = True) 
neighborhood_latitude = df2.loc['M9V']['Latitude']
neighborhood_longitude = df2.loc['M9V']['Longitude']
print(neighborhood_latitude,neighborhood_longitude)
# Out:
# 43.739416399999996 -79.5884369

# %% [markdown]
# ### see what the top 100 venus are within a radius from the centroid of 500 meters

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=T2BNDIDZC1CFMZTGCQQBVTGZVYPZ2TQTPMFORU2TPSO3G0YG&client_secret=EUJE415XKSIHGNHIH01QE1YJJGR1HBFJ2PIW5ZNPWRYMGCG4&v=20180605&ll=43.739416399999996,-79.5884369&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebfc64814a126001ba867b5'},
#  'response': {'headerLocation': 'Rexdale',
#   'headerFullLocation': 'Rexdale, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 9,
#   'suggestedBounds': {'ne': {'lat': 43.7439164045, 'lng': -79.58222007762089},
#    'sw': {'lat': 43.734916395499994, 'lng': -79.59465372237912}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c633939e1621b8d48842553',
#        'name': 'Subway',
#        'location': {'address': '6210 Finch Ave West, Store 103',
#         'crossStreet': 'at Albion Rd.',
#         'lat': 43.74264512142215,
#         'lng': -79.58964323010724,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74264512142215,
#           'lng': -79.58964323010724}],
#         'distance': 372,
#         'postalCode': 'M9V 0A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['6210 Finch Ave West, Store 103 (at Albion Rd.)',
#          'Toronto ON M9V 0A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c633939e1621b8d48842553-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be58dc4cf200f479154133c',
#        'name': 'Shoppers Drug Mart',
#        'location': {'address': '1530 Albion Rd',
#         'crossStreet': 'Albion Mall',
#         'lat': 43.741685,
#         'lng': -79.584487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.741685,
#           'lng': -79.584487}],
#         'distance': 405,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Rd (Albion Mall)',
#          'Etobicoke ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be58dc4cf200f479154133c-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be70e26cf200f47e334153c',
#        'name': 'Popeyes Louisiana Kitchen',
#        'location': {'address': '1530 Albion Rd.',
#         'crossStreet': 'at Kipling Ave. (Albion Centre)',
#         'lat': 43.74120165509377,
#         'lng': -79.58454469276013,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74120165509377,
#           'lng': -79.58454469276013}],
#         'distance': 370,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Rd. (at Kipling Ave. (Albion Centre))',
#          'Etobicoke ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be70e26cf200f47e334153c-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5112b872e4b0c0a78d7bcd27',
#        'name': 'Sunny Foodmart',
#        'location': {'address': '1620 Albion road',
#         'crossStreet': 'Albion Road and Finch Ave',
#         'lat': 43.74184023292111,
#         'lng': -79.59056069637506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74184023292111,
#           'lng': -79.59056069637506}],
#         'distance': 319,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1620 Albion road (Albion Road and Finch Ave)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5112b872e4b0c0a78d7bcd27-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd4738cdfb4a1cd4337535c',
#        'name': 'The Beer Store',
#        'location': {'address': '1530 Albion Rd',
#         'crossStreet': 'Near Finch Ave. W.',
#         'lat': 43.7416936,
#         'lng': -79.5843728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7416936,
#           'lng': -79.5843728}],
#         'distance': 413,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Rd (Near Finch Ave. W.)',
#          'Etobicoke ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd4738cdfb4a1cd4337535c-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b04a05bf964a520c45522e3',
#        'name': "Sheriff's No Frills",
#        'location': {'address': '1530 Albion Rd',
#         'crossStreet': 'at Finch Ave. W.',
#         'lat': 43.741696,
#         'lng': -79.584379,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.741696,
#           'lng': -79.584379}],
#         'distance': 413,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Rd (at Finch Ave. W.)',
#          'Etobicoke ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b04a05bf964a520c45522e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8ba6910c4e41bdaaf7667f',
#        'name': 'Pizza Pizza',
#        'location': {'address': '1530 Albion Road, Unit T25',
#         'lat': 43.74156896801906,
#         'lng': -79.58448886871338,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74156896801906,
#           'lng': -79.58448886871338}],
#         'distance': 397,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Road, Unit T25',
#          'Etobicoke ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8ba6910c4e41bdaaf7667f-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1951d6834e2d7f2d3a2a80',
#        'name': "McDonald's",
#        'location': {'address': '1530 Albion Road, Unit F-1',
#         'lat': 43.7417571,
#         'lng': -79.5842303,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7417571,
#           'lng': -79.5842303}],
#         'distance': 427,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Road, Unit F-1',
#          'Toronto ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1951d6834e2d7f2d3a2a80-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b776533f964a5208f972ee3',
#        'name': 'Rogers Plus',
#        'location': {'address': '1530 Albion Road  Unit # 49',
#         'lat': 43.74131169099951,
#         'lng': -79.58526313098758,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74131169099951,
#           'lng': -79.58526313098758}],
#         'distance': 331,
#         'postalCode': 'M9V 1B4',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1530 Albion Road  Unit # 49',
#          'Etobicoke ON M9V 1B4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d126951735',
#          'name': 'Video Store',
#          'pluralName': 'Video Stores',
#          'shortName': 'Video Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/video_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b776533f964a5208f972ee3-8'}]}]}}

# %% [markdown]
# ### function that extracts the category of the venue

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) # flatten JSON
nearby_venues
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
# 5              0  [{'summary': 'This spot is popular', 'type': '...
# 6              0  [{'summary': 'This spot is popular', 'type': '...
# 7              0  [{'summary': 'This spot is popular', 'type': '...
# 8              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-4c633939e1621b8d48842553-0
# 1  e-0-4be58dc4cf200f479154133c-1
# 2  e-0-4be70e26cf200f47e334153c-2
# 3  e-0-5112b872e4b0c0a78d7bcd27-3
# 4  e-0-4cd4738cdfb4a1cd4337535c-4
# 5  e-0-4b04a05bf964a520c45522e3-5
# 6  e-0-4d8ba6910c4e41bdaaf7667f-6
# 7  e-0-4c1951d6834e2d7f2d3a2a80-7
# 8  e-0-4b776533f964a5208f972ee3-8
#
#                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 1  [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2  [{'id': '4d4ae6fc7a7b7dea34424761', 'name': 'F...
# 3  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 4  [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 5  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 6  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 7  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 8  [{'id': '4bf58dd8d48988d126951735', 'name': 'V...
#
#                    venue.id          venue.location.address venue.location.cc  \
# 0  4c633939e1621b8d48842553  6210 Finch Ave West, Store 103                CA
# 1  4be58dc4cf200f479154133c                  1530 Albion Rd                CA
# 2  4be70e26cf200f47e334153c                 1530 Albion Rd.                CA
# 3  5112b872e4b0c0a78d7bcd27                1620 Albion road                CA
# 4  4cd4738cdfb4a1cd4337535c                  1530 Albion Rd                CA
# 5  4b04a05bf964a520c45522e3                  1530 Albion Rd                CA
# 6  4d8ba6910c4e41bdaaf7667f      1530 Albion Road, Unit T25                CA
# 7  4c1951d6834e2d7f2d3a2a80      1530 Albion Road, Unit F-1                CA
# 8  4b776533f964a5208f972ee3     1530 Albion Road  Unit # 49                CA
#
#   venue.location.city venue.location.country       venue.location.crossStreet  \
# 0             Toronto                 Canada                    at Albion Rd.
# 1           Etobicoke                 Canada                      Albion Mall
# 2           Etobicoke                 Canada  at Kipling Ave. (Albion Centre)
# 3             Toronto                 Canada        Albion Road and Finch Ave
# 4           Etobicoke                 Canada               Near Finch Ave. W.
# 5           Etobicoke                 Canada                 at Finch Ave. W.
# 6           Etobicoke                 Canada                              NaN
# 7             Toronto                 Canada                              NaN
# 8           Etobicoke                 Canada                              NaN
#
#    venue.location.distance                    venue.location.formattedAddress  \
# 0                      372  [6210 Finch Ave West, Store 103 (at Albion Rd....
# 1                      405  [1530 Albion Rd (Albion Mall), Etobicoke ON M9...
# 2                      370  [1530 Albion Rd. (at Kipling Ave. (Albion Cent...
# 3                      319  [1620 Albion road (Albion Road and Finch Ave),...
# 4                      413  [1530 Albion Rd (Near Finch Ave. W.), Etobicok...
# 5                      413  [1530 Albion Rd (at Finch Ave. W.), Etobicoke ...
# 6                      397  [1530 Albion Road, Unit T25, Etobicoke ON M9V ...
# 7                      427  [1530 Albion Road, Unit F-1, Toronto ON M9V 1B...
# 8                      331  [1530 Albion Road  Unit # 49, Etobicoke ON M9V...
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 43.74264512142215...           43.742645
# 1  [{'label': 'display', 'lat': 43.741685, 'lng':...           43.741685
# 2  [{'label': 'display', 'lat': 43.74120165509377...           43.741202
# 3  [{'label': 'display', 'lat': 43.74184023292111...           43.741840
# 4  [{'label': 'display', 'lat': 43.7416936, 'lng'...           43.741694
# 5  [{'label': 'display', 'lat': 43.741696, 'lng':...           43.741696
# 6  [{'label': 'display', 'lat': 43.74156896801906...           43.741569
# 7  [{'label': 'display', 'lat': 43.7417571, 'lng'...           43.741757
# 8  [{'label': 'display', 'lat': 43.74131169099951...           43.741312
#
#    venue.location.lng venue.location.postalCode venue.location.state  \
# 0          -79.589643                   M9V 0A1                   ON
# 1          -79.584487                   M9V 1B4                   ON
# 2          -79.584545                   M9V 1B4                   ON
# 3          -79.590561                       NaN                   ON
# 4          -79.584373                   M9V 1B4                   ON
# 5          -79.584379                   M9V 1B4                   ON
# 6          -79.584489                   M9V 1B4                   ON
# 7          -79.584230                   M9V 1B4                   ON
# 8          -79.585263                   M9V 1B4                   ON
#
#                   venue.name  venue.photos.count venue.photos.groups
# 0                     Subway                   0                  []
# 1         Shoppers Drug Mart                   0                  []
# 2  Popeyes Louisiana Kitchen                   0                  []
# 3             Sunny Foodmart                   0                  []
# 4             The Beer Store                   0                  []
# 5        Sheriff's No Frills                   0                  []
# 6                Pizza Pizza                   0                  []
# 7                 McDonald's                   0                  []
# 8                Rogers Plus                   0                  []

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                         name           categories        lat        lng
# 0                     Subway       Sandwich Place  43.742645 -79.589643
# 1         Shoppers Drug Mart             Pharmacy  43.741685 -79.584487
# 2  Popeyes Louisiana Kitchen  Fried Chicken Joint  43.741202 -79.584545
# 3             Sunny Foodmart        Grocery Store  43.741840 -79.590561
# 4             The Beer Store           Beer Store  43.741694 -79.584373

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 9 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

df2
# Out:
#                     Borough\n  \
# Postal Code
# M3A                North York
# M4A                North York
# M5A          Downtown Toronto
# M6A                North York
# M7A          Downtown Toronto
# M9A                 Etobicoke
# M1B               Scarborough
# M3B                North York
# M4B                 East York
# M5B          Downtown Toronto
# M6B                North York
# M9B                 Etobicoke
# M1C               Scarborough
# M3C                North York
# M4C                 East York
# M5C          Downtown Toronto
# M6C                      York
# M9C                 Etobicoke
# M1E               Scarborough
# M4E              East Toronto
# M5E          Downtown Toronto
# M6E                      York
# M1G               Scarborough
# M4G                 East York
# M5G          Downtown Toronto
# M6G          Downtown Toronto
# M1H               Scarborough
# M2H                North York
# M3H                North York
# M4H                 East York
# ...                       ...
# M4R           Central Toronto
# M5R           Central Toronto
# M6R              West Toronto
# M7R               Mississauga
# M9R                 Etobicoke
# M1S               Scarborough
# M4S           Central Toronto
# M5S          Downtown Toronto
# M6S              West Toronto
# M1T               Scarborough
# M4T           Central Toronto
# M5T          Downtown Toronto
# M1V               Scarborough
# M4V           Central Toronto
# M5V          Downtown Toronto
# M8V                 Etobicoke
# M9V                 Etobicoke
# M1W               Scarborough
# M4W          Downtown Toronto
# M5W          Downtown Toronto
# M8W                 Etobicoke
# M9W                 Etobicoke
# M1X               Scarborough
# M4X          Downtown Toronto
# M5X          Downtown Toronto
# M8X                 Etobicoke
# M4Y          Downtown Toronto
# M7Y              East Toronto
# M8Y                 Etobicoke
# M8Z                 Etobicoke
#
#                                                 Neighborhood\n   Latitude  \
# Postal Code
# M3A                                                  Parkwoods  43.753259
# M4A                                           Victoria Village  43.725882
# M5A                                  Regent Park, Harbourfront  43.654260
# M6A                           Lawrence Manor, Lawrence Heights  43.718518
# M7A                Queen's Park, Ontario Provincial Government  43.662301
# M9A                                           Islington Avenue  43.667856
# M1B                                             Malvern, Rouge  43.806686
# M3B                                                  Don Mills  43.745906
# M4B                            Parkview Hill, Woodbine Gardens  43.706397
# M5B                                   Garden District, Ryerson  43.657162
# M6B                                                  Glencairn  43.709577
# M9B          West Deane Park, Princess Gardens, Martin Grov...  43.650943
# M1C                     Rouge Hill, Port Union, Highland Creek  43.784535
# M3C                                                  Don Mills  43.725900
# M4C                                           Woodbine Heights  43.695344
# M5C                                             St. James Town  43.651494
# M6C                                         Humewood-Cedarvale  43.693781
# M9C          Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515
# M1E                          Guildwood, Morningside, West Hill  43.763573
# M4E                                                The Beaches  43.676357
# M5E                                                Berczy Park  43.644771
# M6E                                        Caledonia-Fairbanks  43.689026
# M1G                                                     Woburn  43.770992
# M4G                                                    Leaside  43.709060
# M5G                                         Central Bay Street  43.657952
# M6G                                                   Christie  43.669542
# M1H                                                  Cedarbrae  43.773136
# M2H                                          Hillcrest Village  43.803762
# M3H            Bathurst Manor, Wilson Heights, Downsview North  43.754328
# M4H                                           Thorncliffe Park  43.705369
# ...                                                        ...        ...
# M4R                                         North Toronto West  43.715383
# M5R                        The Annex, North Midtown, Yorkville  43.672710
# M6R                                     Parkdale, Roncesvalles  43.648960
# M7R                      Canada Post Gateway Processing Centre  43.636966
# M9R          Kingsview Village, St. Phillips, Martin Grove ...  43.688905
# M1S                                                  Agincourt  43.794200
# M4S                                                 Davisville  43.704324
# M5S                             University of Toronto, Harbord  43.662696
# M6S                                         Runnymede, Swansea  43.651571
# M1T                    Clarks Corners, Tam O'Shanter, Sullivan  43.781638
# M4T                                Moore Park, Summerhill East  43.689574
# M5T                  Kensington Market, Chinatown, Grange Park  43.653206
# M1V          Milliken, Agincourt North, Steeles East, L'Amo...  43.815252
# M4V          Summerhill West, Rathnelly, South Hill, Forest...  43.686412
# M5V          CN Tower, King and Spadina, Railway Lands, Har...  43.628947
# M8V               New Toronto, Mimico South, Humber Bay Shores  43.605647
# M9V          South Steeles, Silverstone, Humbergate, Jamest...  43.739416
# M1W                              Steeles West, L'Amoreaux West  43.799525
# M4W                                                   Rosedale  43.679563
# M5W                                             Stn A PO Boxes  43.646435
# M8W                                     Alderwood, Long Branch  43.602414
# M9W                                                  Northwest  43.706748
# M1X                                                Upper Rouge  43.836125
# M4X                                St. James Town, Cabbagetown  43.667967
# M5X                     First Canadian Place, Underground city  43.648429
# M8X              The Kingsway, Montgomery Road, Old Mill North  43.653654
# M4Y                                       Church and Wellesley  43.665860
# M7Y                      Business reply mail Processing Centre  43.662744
# M8Y          Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258
# M8Z          Mimico NW, The Queensway West, South of Bloor,...  43.628841
#
#              Longitude
# Postal Code
# M3A         -79.329656
# M4A         -79.315572
# M5A         -79.360636
# M6A         -79.464763
# M7A         -79.389494
# M9A         -79.532242
# M1B         -79.194353
# M3B         -79.352188
# M4B         -79.309937
# M5B         -79.378937
# M6B         -79.445073
# M9B         -79.554724
# M1C         -79.160497
# M3C         -79.340923
# M4C         -79.318389
# M5C         -79.375418
# M6C         -79.428191
# M9C         -79.577201
# M1E         -79.188711
# M4E         -79.293031
# M5E         -79.373306
# M6E         -79.453512
# M1G         -79.216917
# M4G         -79.363452
# M5G         -79.387383
# M6G         -79.422564
# M1H         -79.239476
# M2H         -79.363452
# M3H         -79.442259
# M4H         -79.349372
# ...                ...
# M4R         -79.405678
# M5R         -79.405678
# M6R         -79.456325
# M7R         -79.615819
# M9R         -79.554724
# M1S         -79.262029
# M4S         -79.388790
# M5S         -79.400049
# M6S         -79.484450
# M1T         -79.304302
# M4T         -79.383160
# M5T         -79.400049
# M1V         -79.284577
# M4V         -79.400049
# M5V         -79.394420
# M8V         -79.501321
# M9V         -79.588437
# M1W         -79.318389
# M4W         -79.377529
# M5W         -79.374846
# M8W         -79.543484
# M9W         -79.594054
# M1X         -79.205636
# M4X         -79.367675
# M5X         -79.382280
# M8X         -79.506944
# M4Y         -79.383160
# M7Y         -79.321558
# M8Y         -79.498509
# M8Z         -79.520999
#
# [103 rows x 4 columns]

# %%
venues = getNearbyVenues(names=df2['Borough\n'],latitudes=df2['Latitude'],longitudes=df2['Longitude'])
# Out:
# North York
# North York
# Downtown Toronto
# North York
# Downtown Toronto
# Etobicoke
# Scarborough
# North York
# East York
# Downtown Toronto
# North York
# Etobicoke
# Scarborough
# North York
# East York
# Downtown Toronto
# York
# Etobicoke
# Scarborough
# East Toronto
# Downtown Toronto
# York
# Scarborough
# East York
# Downtown Toronto
# Downtown Toronto
# Scarborough
# North York
# North York
# East York
# Downtown Toronto
# West Toronto
# Scarborough
# North York
# North York
# East York
# Downtown Toronto
# West Toronto
# Scarborough
# North York
# North York
# East Toronto
# Downtown Toronto
# West Toronto
# Scarborough
# North York
# North York
# East Toronto
# Downtown Toronto
# North York
# North York
# Scarborough
# North York
# North York
# East Toronto
# North York
# York
# North York
# Scarborough
# North York
# North York
# Central Toronto
# Central Toronto
# York
# York
# Scarborough
# North York
# Central Toronto
# Central Toronto
# West Toronto
# Etobicoke
# Scarborough
# North York
# Central Toronto
# Central Toronto
# West Toronto
# Mississauga
# Etobicoke
# Scarborough
# Central Toronto
# Downtown Toronto
# West Toronto
# Scarborough
# Central Toronto
# Downtown Toronto
# Scarborough
# Central Toronto
# Downtown Toronto
# Etobicoke
# Etobicoke
# Scarborough
# Downtown Toronto
# Downtown Toronto
# Etobicoke
# Etobicoke
# Scarborough
# Downtown Toronto
# Downtown Toronto
# Etobicoke
# Downtown Toronto
# East Toronto
# Etobicoke
# Etobicoke

# %%
venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   North York              43.753259              -79.329656
# 1   North York              43.753259              -79.329656
# 2   North York              43.753259              -79.329656
# 3   North York              43.725882              -79.315572
# 4   North York              43.725882              -79.315572
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0                    Brookbanks Park       43.751976       -79.332140
# 1                      Variety Store       43.751974       -79.333114
# 2  Corrosion Service Company Limited       43.752432       -79.334661
# 3             Victoria Village Arena       43.723481       -79.315635
# 4                        Tim Hortons       43.725517       -79.313103
#
#                Venue Category
# 0                        Park
# 1           Food & Drink Shop
# 2  Construction & Landscaping
# 3                Hockey Arena
# 4                 Coffee Shop

# %%
venues.groupby('Neighborhood').count()
# Out:
#                   Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Central Toronto                     116                     116    116
# Downtown Toronto                   1211                    1211   1211
# East Toronto                        125                     125    125
# East York                            77                      77     77
# Etobicoke                            65                      65     65
# Mississauga                          12                      12     12
# North York                          241                     241    241
# Scarborough                          90                      90     90
# West Toronto                        154                     154    154
# York                                 17                      17     17
#
#                   Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Central Toronto              116              116             116
# Downtown Toronto            1211             1211            1211
# East Toronto                 125              125             125
# East York                     77               77              77
# Etobicoke                     65               65              65
# Mississauga                   12               12              12
# North York                   241              241             241
# Scarborough                   90               90              90
# West Toronto                 154              154             154
# York                          17               17              17

# %%
grouped = venues.groupby('Neighborhood').mean().reset_index()
grouped
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   Central Toronto              43.698145              -79.398350
# 1  Downtown Toronto              43.652147              -79.381591
# 2      East Toronto              43.668959              -79.335900
# 3         East York              43.704947              -79.345237
# 4         Etobicoke              43.652143              -79.540279
# 5       Mississauga              43.636966              -79.615819
# 6        North York              43.756421              -79.399938
# 7       Scarborough              43.763872              -79.269537
# 8      West Toronto              43.651636              -79.448522
# 9              York              43.688730              -79.469888
#
#    Venue Latitude  Venue Longitude
# 0       43.698943       -79.396973
# 1       43.652334       -79.381841
# 2       43.668759       -79.335832
# 3       43.704860       -79.344131
# 4       43.651636       -79.539964
# 5       43.637472       -79.619684
# 6       43.756037       -79.399792
# 7       43.763759       -79.269699
# 8       43.651602       -79.447349
# 9       43.688234       -79.470190

# %%
num_top_venues = 5

for hood in grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = grouped[grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Central Toronto----
#                     venue  freq
# 0   Neighborhood Latitude  43.7
# 1          Venue Latitude  43.7
# 2  Neighborhood Longitude -79.4
# 3         Venue Longitude -79.4
#
#
# ----Downtown Toronto----
#                     venue   freq
# 0   Neighborhood Latitude  43.65
# 1          Venue Latitude  43.65
# 2  Neighborhood Longitude -79.38
# 3         Venue Longitude -79.38
#
#
# ----East Toronto----
#                     venue   freq
# 0   Neighborhood Latitude  43.67
# 1          Venue Latitude  43.67
# 2  Neighborhood Longitude -79.34
# 3         Venue Longitude -79.34
#
#
# ----East York----
#                     venue   freq
# 0   Neighborhood Latitude  43.70
# 1          Venue Latitude  43.70
# 2         Venue Longitude -79.34
# 3  Neighborhood Longitude -79.35
#
#
# ----Etobicoke----
#                     venue   freq
# 0   Neighborhood Latitude  43.65
# 1          Venue Latitude  43.65
# 2  Neighborhood Longitude -79.54
# 3         Venue Longitude -79.54
#
#
# ----Mississauga----
#                     venue   freq
# 0   Neighborhood Latitude  43.64
# 1          Venue Latitude  43.64
# 2  Neighborhood Longitude -79.62
# 3         Venue Longitude -79.62
#
#
# ----North York----
#                     venue   freq
# 0   Neighborhood Latitude  43.76
# 1          Venue Latitude  43.76
# 2  Neighborhood Longitude -79.40
# 3         Venue Longitude -79.40
#
#
# ----Scarborough----
#                     venue   freq
# 0   Neighborhood Latitude  43.76
# 1          Venue Latitude  43.76
# 2  Neighborhood Longitude -79.27
# 3         Venue Longitude -79.27
#
#
# ----West Toronto----
#                     venue   freq
# 0   Neighborhood Latitude  43.65
# 1          Venue Latitude  43.65
# 2  Neighborhood Longitude -79.45
# 3         Venue Longitude -79.45
#
#
# ----York----
#                     venue   freq
# 0   Neighborhood Latitude  43.69
# 1          Venue Latitude  43.69
# 2  Neighborhood Longitude -79.47
# 3         Venue Longitude -79.47

# %%
# set number of clusters
kclusters = 5

grouped_clustering = grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 0, 0, 0, 3, 3, 4, 2, 1, 1], dtype=int32)

# %%
merged = grouped

# add clustering labels
merged['Cluster Labels'] = kmeans.labels_

merged # check the last columns!
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   Central Toronto              43.698145              -79.398350
# 1  Downtown Toronto              43.652147              -79.381591
# 2      East Toronto              43.668959              -79.335900
# 3         East York              43.704947              -79.345237
# 4         Etobicoke              43.652143              -79.540279
# 5       Mississauga              43.636966              -79.615819
# 6        North York              43.756421              -79.399938
# 7       Scarborough              43.763872              -79.269537
# 8      West Toronto              43.651636              -79.448522
# 9              York              43.688730              -79.469888
#
#    Venue Latitude  Venue Longitude  Cluster Labels
# 0       43.698943       -79.396973               4
# 1       43.652334       -79.381841               0
# 2       43.668759       -79.335832               0
# 3       43.704860       -79.344131               0
# 4       43.651636       -79.539964               3
# 5       43.637472       -79.619684               3
# 6       43.756037       -79.399792               4
# 7       43.763759       -79.269699               2
# 8       43.651602       -79.447349               1
# 9       43.688234       -79.470190               1
